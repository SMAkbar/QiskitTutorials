# %%
import gym
import numpy as np
import matplotlib.pyplot as plt 

env = gym.make("MountainCar-v0")
#env.reset()

LEARNING_RATE = 0.1
DISCOUNT = 0.95
EPISODES = 2000

SHOW_EVERY = 500


#print(env.observation_space.high)
#print(env.observation_space.low)
#print(env.action_space.n)

DISCRETE_OS_SIZE = [20] * len(env.observation_space.high)
discrete_os_win_size = (env.observation_space.high - env.observation_space.low) / DISCRETE_OS_SIZE

#print(discrete_os_win_size)

epsilon = 0.5
START_EPSILON_DECAYING = 1
END_EPISODE_DECAYING = EPISODES // 2

epsilon_decay_value = epsilon / (END_EPISODE_DECAYING - START_EPSILON_DECAYING)


q_table = np.random.uniform(low=-2, high=0, size=(DISCRETE_OS_SIZE + [env.action_space.n]))

#print(q_table.shape)

ep_rewards = []
aggr_ep_rewards = {'ep': [], 'avg': [], 'min':[], 'max':[]}



def get_discrete_state(state):
    discrete_state = (state - env.observation_space.low) / discrete_os_win_size
    return tuple(discrete_state.astype(np.int))


for episode in range(EPISODES):
    episode_reward = 0
    if episode % SHOW_EVERY == 0:
        print(episode)
        render = True
    else:
        render = False
    
    done = False
    discrete_state = get_discrete_state(env.reset())

    #print(discrete_state)

    #print(np.argmax(q_table[discrete_state]))
    

    while not done:
        if np.random.random() > epsilon:
            action = np.argmax(q_table[discrete_state])
        else:
            action = np.random.randint(0, env.action_space.n)
        action = np.argmax(q_table[discrete_state])
        new_state, reward, done, _ = env.step(action)
        episode_reward += reward
        new_discrete_state = get_discrete_state(new_state)
        
        #print(reward, new_state)
        if render:
            env.render()
            
        if not done:
            max_future_q = np.max(q_table[new_discrete_state])
            current_q = q_table[discrete_state + (action, )]        
            new_q = (1 - LEARNING_RATE) * current_q + LEARNING_RATE * (reward + DISCOUNT * max_future_q)
            q_table[discrete_state + (action, )] = new_q                                                          
        elif new_state[0] >= env.goal_position:  
            print(f"We made in on episode {episode}")
            q_table[discrete_state + (action, )] = 0

        discrete_state = new_discrete_state
        
    if END_EPISODE_DECAYING >= episode  >= START_EPSILON_DECAYING:
        epsilon -= epsilon_decay_value
        
    ep_rewards.append(episode_reward)
    
    if not episode % SHOW_EVERY:
        np.save(f"qtables/{episode}-qtable.npy", q_table)
        average_reward = sum(ep_rewards[-SHOW_EVERY:])/len(ep_rewards[-SHOW_EVERY:])
        aggr_ep_rewards['ep'].append(episode)
        aggr_ep_rewards['avg'].append(average_reward)
        aggr_ep_rewards['min'].append(min(ep_rewards[-SHOW_EVERY:]))
        aggr_ep_rewards['max'].append(max(ep_rewards[-SHOW_EVERY:]))
        
        print(f"Episdoe: {episode} avg: {average_reward} min: {min(ep_rewards[-SHOW_EVERY:])} max; {max(ep_rewards[-SHOW_EVERY:])}")


env.close()

plt.plot(aggr_ep_rewards['ep'], aggr_ep_rewards['avg'], label="avg")
plt.plot(aggr_ep_rewards['ep'], aggr_ep_rewards['min'], label="min")
plt.plot(aggr_ep_rewards['ep'], aggr_ep_rewards['max'], label="max")
plt.legend(loc=4)
plt.show()
# Out:
# 0
# Episdoe: 0 avg: -200.0 min: -200.0 max; -200.0
# We made in on episode 290
# We made in on episode 457
# We made in on episode 464
# We made in on episode 488
# We made in on episode 490
# We made in on episode 493
# We made in on episode 494
# 500
# Episdoe: 500 avg: -199.75 min: -200.0 max; -165.0
# We made in on episode 555
# We made in on episode 558
# We made in on episode 560
# We made in on episode 561
# We made in on episode 562
# We made in on episode 563
# We made in on episode 564
# We made in on episode 565
# We made in on episode 569
# We made in on episode 571
# We made in on episode 582
# We made in on episode 611
# We made in on episode 612
# We made in on episode 627
# We made in on episode 642
# We made in on episode 723
# We made in on episode 725
# We made in on episode 728
# We made in on episode 738
# We made in on episode 807
# We made in on episode 808
# We made in on episode 812
# We made in on episode 828
# We made in on episode 838
# We made in on episode 849
# We made in on episode 852
# We made in on episode 856
# We made in on episode 859
# We made in on episode 873
# We made in on episode 881
# We made in on episode 900
# We made in on episode 995
# 1000
# Episdoe: 1000 avg: -198.732 min: -200.0 max; -160.0
# We made in on episode 1001
# We made in on episode 1014
# We made in on episode 1019
# We made in on episode 1023
# We made in on episode 1024
# We made in on episode 1025
# We made in on episode 1026
# We made in on episode 1029
# We made in on episode 1031
# We made in on episode 1035
# We made in on episode 1036
# We made in on episode 1038
# We made in on episode 1039
# We made in on episode 1040
# We made in on episode 1047
# We made in on episode 1048
# We made in on episode 1049
# We made in on episode 1051
# We made in on episode 1054
# We made in on episode 1057
# We made in on episode 1058
# We made in on episode 1059
# We made in on episode 1060
# We made in on episode 1061
# We made in on episode 1062
# We made in on episode 1063
# We made in on episode 1064
# We made in on episode 1065
# We made in on episode 1066
# We made in on episode 1067
# We made in on episode 1068
# We made in on episode 1069
# We made in on episode 1070
# We made in on episode 1071
# We made in on episode 1072
# We made in on episode 1073
# We made in on episode 1074
# We made in on episode 1075
# We made in on episode 1077
# We made in on episode 1078
# We made in on episode 1079
# We made in on episode 1080
# We made in on episode 1081
# We made in on episode 1085
# We made in on episode 1086
# We made in on episode 1087
# We made in on episode 1088
# We made in on episode 1089
# We made in on episode 1091
# We made in on episode 1093
# We made in on episode 1094
# We made in on episode 1096
# We made in on episode 1100
# We made in on episode 1104
# We made in on episode 1111
# We made in on episode 1112
# We made in on episode 1113
# We made in on episode 1114
# We made in on episode 1115
# We made in on episode 1116
# We made in on episode 1120
# We made in on episode 1122
# We made in on episode 1131
# We made in on episode 1132
# We made in on episode 1133
# We made in on episode 1134
# We made in on episode 1146
# We made in on episode 1205
# We made in on episode 1213
# We made in on episode 1225
# We made in on episode 1228
# We made in on episode 1229
# We made in on episode 1235
# We made in on episode 1253
# We made in on episode 1255
# We made in on episode 1257
# We made in on episode 1258
# We made in on episode 1260
# We made in on episode 1261
# We made in on episode 1264
# We made in on episode 1268
# We made in on episode 1269
# We made in on episode 1271
# We made in on episode 1272
# We made in on episode 1273
# We made in on episode 1281
# We made in on episode 1289
# We made in on episode 1295
# We made in on episode 1301
# We made in on episode 1304
# We made in on episode 1305
# We made in on episode 1306
# We made in on episode 1310
# We made in on episode 1312
# We made in on episode 1314
# We made in on episode 1404
# We made in on episode 1407
# We made in on episode 1409
# We made in on episode 1410
# We made in on episode 1412
# We made in on episode 1413
# We made in on episode 1414
# We made in on episode 1416
# We made in on episode 1417
# We made in on episode 1418
# We made in on episode 1421
# We made in on episode 1423
# We made in on episode 1424
# We made in on episode 1428
# We made in on episode 1431
# We made in on episode 1432
# We made in on episode 1437
# We made in on episode 1439
# We made in on episode 1469
# We made in on episode 1475
# We made in on episode 1480
# We made in on episode 1483
# We made in on episode 1488
# We made in on episode 1489
# We made in on episode 1490
# We made in on episode 1492
# We made in on episode 1493
# We made in on episode 1494
# We made in on episode 1495
# We made in on episode 1496
# We made in on episode 1497
# 1500
# Episdoe: 1500 avg: -195.086 min: -200.0 max; -115.0
# We made in on episode 1501
# We made in on episode 1502
# We made in on episode 1505
# We made in on episode 1508
# We made in on episode 1513
# We made in on episode 1516
# We made in on episode 1524
# We made in on episode 1528
# We made in on episode 1532
# We made in on episode 1539
# We made in on episode 1540
# We made in on episode 1545
# We made in on episode 1550
# We made in on episode 1558
# We made in on episode 1561
# We made in on episode 1570
# We made in on episode 1571
# We made in on episode 1572
# We made in on episode 1573
# We made in on episode 1574
# We made in on episode 1575
# We made in on episode 1576
# We made in on episode 1577
# We made in on episode 1579
# We made in on episode 1580
# We made in on episode 1582
# We made in on episode 1584
# We made in on episode 1585
# We made in on episode 1586
# We made in on episode 1587
# We made in on episode 1588
# We made in on episode 1589
# We made in on episode 1592
# We made in on episode 1595
# We made in on episode 1597
# We made in on episode 1600
# We made in on episode 1602
# We made in on episode 1604
# We made in on episode 1605
# We made in on episode 1606
# We made in on episode 1608
# We made in on episode 1609
# We made in on episode 1610
# We made in on episode 1611
# We made in on episode 1612
# We made in on episode 1613
# We made in on episode 1615
# We made in on episode 1616
# We made in on episode 1617
# We made in on episode 1620
# We made in on episode 1621
# We made in on episode 1622
# We made in on episode 1623
# We made in on episode 1624
# We made in on episode 1625
# We made in on episode 1627
# We made in on episode 1628
# We made in on episode 1629
# We made in on episode 1630
# We made in on episode 1631
# We made in on episode 1632
# We made in on episode 1633
# We made in on episode 1634
# We made in on episode 1635
# We made in on episode 1636
# We made in on episode 1637
# We made in on episode 1638
# We made in on episode 1639
# We made in on episode 1640
# We made in on episode 1641
# We made in on episode 1642
# We made in on episode 1643
# We made in on episode 1644
# We made in on episode 1645
# We made in on episode 1646
# We made in on episode 1647
# We made in on episode 1648
# We made in on episode 1649
# We made in on episode 1650
# We made in on episode 1651
# We made in on episode 1653
# We made in on episode 1654
# We made in on episode 1655
# We made in on episode 1656
# We made in on episode 1657
# We made in on episode 1658
# We made in on episode 1659
# We made in on episode 1660
# We made in on episode 1661
# We made in on episode 1662
# We made in on episode 1663
# We made in on episode 1664
# We made in on episode 1665
# We made in on episode 1666
# We made in on episode 1667
# We made in on episode 1668
# We made in on episode 1669
# We made in on episode 1670
# We made in on episode 1671
# We made in on episode 1672
# We made in on episode 1673
# We made in on episode 1674
# We made in on episode 1675
# We made in on episode 1676
# We made in on episode 1677
# We made in on episode 1678
# We made in on episode 1679
# We made in on episode 1680
# We made in on episode 1681
# We made in on episode 1682
# We made in on episode 1683
# We made in on episode 1684
# We made in on episode 1685
# We made in on episode 1686
# We made in on episode 1687
# We made in on episode 1688
# We made in on episode 1689
# We made in on episode 1690
# We made in on episode 1691
# We made in on episode 1692
# We made in on episode 1693
# We made in on episode 1694
# We made in on episode 1695
# We made in on episode 1696
# We made in on episode 1697
# We made in on episode 1698
# We made in on episode 1699
# We made in on episode 1700
# We made in on episode 1701
# We made in on episode 1702
# We made in on episode 1703
# We made in on episode 1705
# We made in on episode 1706
# We made in on episode 1707
# We made in on episode 1709
# We made in on episode 1710
# We made in on episode 1711
# We made in on episode 1712
# We made in on episode 1713
# We made in on episode 1715
# We made in on episode 1716
# We made in on episode 1717
# We made in on episode 1718
# We made in on episode 1721
# We made in on episode 1722
# We made in on episode 1723
# We made in on episode 1725
# We made in on episode 1729
# We made in on episode 1730
# We made in on episode 1732
# We made in on episode 1733
# We made in on episode 1734
# We made in on episode 1735
# We made in on episode 1736
# We made in on episode 1738
# We made in on episode 1740
# We made in on episode 1741
# We made in on episode 1742
# We made in on episode 1743
# We made in on episode 1745
# We made in on episode 1746
# We made in on episode 1747
# We made in on episode 1749
# We made in on episode 1751
# We made in on episode 1752
# We made in on episode 1753
# We made in on episode 1756
# We made in on episode 1757
# We made in on episode 1758
# We made in on episode 1759
# We made in on episode 1760
# We made in on episode 1763
# We made in on episode 1765
# We made in on episode 1769
# We made in on episode 1770
# We made in on episode 1773
# We made in on episode 1774
# We made in on episode 1776
# We made in on episode 1777
# We made in on episode 1781
# We made in on episode 1784
# We made in on episode 1794
# We made in on episode 1798
# We made in on episode 1799
# We made in on episode 1800
# We made in on episode 1801
# We made in on episode 1802
# We made in on episode 1809
# We made in on episode 1820
# We made in on episode 1821
# We made in on episode 1824
# We made in on episode 1825
# We made in on episode 1826
# We made in on episode 1827
# We made in on episode 1828
# We made in on episode 1829
# We made in on episode 1830
# We made in on episode 1831
# We made in on episode 1835
# We made in on episode 1844
# We made in on episode 1845
# We made in on episode 1846
# We made in on episode 1847
# We made in on episode 1848
# We made in on episode 1849
# We made in on episode 1851
# We made in on episode 1852
# We made in on episode 1853
# We made in on episode 1854
# We made in on episode 1855
# We made in on episode 1856
# We made in on episode 1857
# We made in on episode 1860
# We made in on episode 1862
# We made in on episode 1863
# We made in on episode 1864
# We made in on episode 1865
# We made in on episode 1866
# We made in on episode 1867
# We made in on episode 1870
# We made in on episode 1872
# We made in on episode 1873
# We made in on episode 1874
# We made in on episode 1875
# We made in on episode 1876
# We made in on episode 1877
# We made in on episode 1878
# We made in on episode 1879
# We made in on episode 1880
# We made in on episode 1881
# We made in on episode 1882
# We made in on episode 1883
# We made in on episode 1884
# We made in on episode 1885
# We made in on episode 1887
# We made in on episode 1888
# We made in on episode 1889
# We made in on episode 1890
# We made in on episode 1891
# We made in on episode 1892
# We made in on episode 1893
# We made in on episode 1894
# We made in on episode 1896
# We made in on episode 1897
# We made in on episode 1898
# We made in on episode 1899
# We made in on episode 1900
# We made in on episode 1901
# We made in on episode 1902
# We made in on episode 1903
# We made in on episode 1904
# We made in on episode 1906
# We made in on episode 1907
# We made in on episode 1908
# We made in on episode 1909
# We made in on episode 1910
# We made in on episode 1911
# We made in on episode 1913
# We made in on episode 1915
# We made in on episode 1916
# We made in on episode 1917
# We made in on episode 1918
# We made in on episode 1919
# We made in on episode 1921
# We made in on episode 1922
# We made in on episode 1923
# We made in on episode 1924
# We made in on episode 1925
# We made in on episode 1927
# We made in on episode 1928
# We made in on episode 1929
# We made in on episode 1930
# We made in on episode 1931
# We made in on episode 1932
# We made in on episode 1933
# We made in on episode 1934
# We made in on episode 1935
# We made in on episode 1936
# We made in on episode 1937
# We made in on episode 1938
# We made in on episode 1939
# We made in on episode 1940
# We made in on episode 1941
# We made in on episode 1942
# We made in on episode 1943
# We made in on episode 1944
# We made in on episode 1945
# We made in on episode 1946
# We made in on episode 1947
# We made in on episode 1948
# We made in on episode 1949
# We made in on episode 1950
# We made in on episode 1951
# We made in on episode 1952
# We made in on episode 1953
# We made in on episode 1954
# We made in on episode 1955
# We made in on episode 1956
# We made in on episode 1957
# We made in on episode 1958
# We made in on episode 1959
# We made in on episode 1960
# We made in on episode 1961
# We made in on episode 1962
# We made in on episode 1963
# We made in on episode 1964
# We made in on episode 1965
# We made in on episode 1966
# We made in on episode 1967
# We made in on episode 1968
# We made in on episode 1969
# We made in on episode 1970
# We made in on episode 1971
# We made in on episode 1972
# We made in on episode 1973
# We made in on episode 1974
# We made in on episode 1975
# We made in on episode 1976
# We made in on episode 1977
# We made in on episode 1978
# We made in on episode 1979
# We made in on episode 1980
# We made in on episode 1981
# We made in on episode 1982
# We made in on episode 1988
# We made in on episode 1990
# We made in on episode 1991
# We made in on episode 1992
# We made in on episode 1994
# We made in on episode 1997
# We made in on episode 1999
